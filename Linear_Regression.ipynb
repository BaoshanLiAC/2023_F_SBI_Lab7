# %% [markdown]
# # Model Training

# %% [markdown]
# ### scikit - learn
#
# https://scikit-learn.org/stable/
#
# scikitlearn (sklearn) provides simple and efficient tools for predictive data analysis. It is built on NumPy, SciPy, and matplotlib.

# %% [markdown]
# First thing, Import all the libraries

# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 50)

# %%
# import the final data set
df = pd.read_csv('final.csv')
print(df.shape)
df.head()
# Out:
# (1863, 12)
#     price  property_tax  insurance  beds  baths  sqft  lot_size  basement  \
# 0  295850           234         81     1      1   584         0         0
# 1  216500           169         51     1      1   612         0         1
# 2  279900           216         74     1      1   615         0         0
# 3  379900           265         92     1      1   618     33541         0
# 4  340000            88         30     1      1   634         0         0
#
#   property_type  popular  recession  property_age
# 0         Condo        0          1             0
# 1         Condo        0          0            41
# 2         Condo        0          1            49
# 3         Condo        0          0             5
# 4         Condo        0          0            10

# %% [markdown]
# ## One hot encoding
# Converting categorical variables to flag variables

# %%
df = pd.get_dummies(df, columns = ['property_type']) #drop_first

# %%
df.head()
# Out:
#     price  property_tax  insurance  beds  baths  sqft  lot_size  basement  \
# 0  295850           234         81     1      1   584         0         0
# 1  216500           169         51     1      1   612         0         1
# 2  279900           216         74     1      1   615         0         0
# 3  379900           265         92     1      1   618     33541         0
# 4  340000            88         30     1      1   634         0         0
#
#    popular  recession  property_age  property_type_Bunglow  \
# 0        0          1             0                      0
# 1        0          0            41                      0
# 2        0          1            49                      0
# 3        0          0             5                      0
# 4        0          0            10                      0
#
#    property_type_Condo
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
#df.describe()

# %% [markdown]
# **Before you begin modeling, you should split the data in train and test subsets.**
# * Training sets are used to fit and tune your models.
# * Test sets are put aside as "unseen" data to evaluate your models.
# * The `train_test_split()` function splits data into randomized subsets.

# %%
# seperate the target variable
y = df.price

# seperate the features
x = df.drop('price', axis=1)

# df.iloc[:,1:3]

# %%
# import module for train-test split
from sklearn.model_selection import train_test_split

# Split the dataset
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.20, random_state=1234)

# %%
# check records in each split
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((1490, 12), (373, 12), (1490,), (373,))

# %%
# import the model
from sklearn.linear_model import LinearRegression

# train the model
#del model
lrmodel = LinearRegression().fit(xtrain,ytrain)

# %%
# make prediction on train set
ytrain_pred = lrmodel.predict(xtrain)

# %%
# import mean absolute error metric
from sklearn.metrics import mean_absolute_error

# evaluate the model
train_mae = mean_absolute_error(ytrain_pred, ytrain)
train_mae
# Out:
# 97227.57775824104

# %%
# make predictions using the x_test values
ytest_pred = lrmodel.predict(xtest)

# %%
# evaluate the model
test_mae = mean_absolute_error(ytest_pred, ytest)
test_mae
# Out:
# 86427.77989910396

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor().fit(xtrain,ytrain)

# %%
# plotting tree
from sklearn import tree
fig = plt.figure(figsize=(25,20))
tree.plot_tree(dt, filled=True)
plt.show()

# %%
# Prune the tree using hyperparameters
dt = DecisionTreeRegressor(max_depth=3, min_samples_split=30).fit(xtrain,ytrain)
from sklearn import tree
tree.plot_tree(dt, filled=True);

# %%
ytrain_pred = dt.predict(xtrain)
dt_mae = mean_absolute_error(ytrain_pred, ytrain)
print('Train error is',dt_mae)
# Out:
# Train error is 82393.86849553732

# %%
# make predictions using the x_test values
ytest_pred = dt.predict(xtest)

# evaluate the model
test_mae = mean_absolute_error(ytest_pred, ytest)
test_mae
# Out:
# 74837.37947455472

# %% [markdown]
# ## Random Forest Model

# %%
# import Random Forest model from scikit learn
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=200,criterion='absolute_error').fit(xtrain,ytrain)
ytrain_pred = rf.predict(xtrain)
rftrain_mae = mean_absolute_error(ytrain_pred, ytrain)
print('Train error RF model is',rftrain_mae)
# Out:
# Train error RF model is 31247.538385906042

# %%
# make predictions on the x_test values
ytest_pred = rf.predict(xtest)

# evaluate the model
rftest_mae = mean_absolute_error(ytest_pred, ytest)
rftest_mae
# Out:
# 71154.62642761394

# %%
df.corr()
# Out:
#                           price  property_tax  insurance      beds     baths  \
# price                  1.000000      0.558266   0.554583  0.387682  0.398615
# property_tax           0.558266      1.000000   0.983430  0.544898  0.507861
# insurance              0.554583      0.983430   1.000000  0.479399  0.454178
# beds                   0.387682      0.544898   0.479399  1.000000  0.640168
# baths                  0.398615      0.507861   0.454178  0.640168  1.000000
# sqft                   0.486858      0.640393   0.569497  0.688634  0.669070
# lot_size               0.185244      0.218076   0.188731  0.228757  0.186494
# basement               0.109144      0.182701   0.135135  0.413082  0.344052
# popular               -0.148108     -0.208959  -0.173812 -0.430083 -0.197480
# recession             -0.022207     -0.121395  -0.120809 -0.070744 -0.057730
# property_age          -0.005428      0.012119   0.075054 -0.015989 -0.213489
# property_type_Bunglow  0.322641      0.449372   0.410135  0.658729  0.339109
# property_type_Condo   -0.322641     -0.449372  -0.410135 -0.658729 -0.339109
#
#                            sqft  lot_size  basement   popular  recession  \
# price                  0.486858  0.185244  0.109144 -0.148108  -0.022207
# property_tax           0.640393  0.218076  0.182701 -0.208959  -0.121395
# insurance              0.569497  0.188731  0.135135 -0.173812  -0.120809
# beds                   0.688634  0.228757  0.413082 -0.430083  -0.070744
# baths                  0.669070  0.186494  0.344052 -0.197480  -0.057730
# sqft                   1.000000  0.325832  0.270175 -0.270799  -0.078903
# lot_size               0.325832  1.000000  0.061934 -0.092659   0.006077
# basement               0.270175  0.061934  1.000000 -0.198936  -0.047486
# popular               -0.270799 -0.092659 -0.198936  1.000000   0.083255
# recession             -0.078903  0.006077 -0.047486  0.083255   1.000000
# property_age          -0.284702 -0.042227 -0.018488 -0.083813   0.097146
# property_type_Bunglow  0.525699  0.250534  0.253299 -0.303769  -0.053224
# property_type_Condo   -0.525699 -0.250534 -0.253299  0.303769   0.053224
#
#                        property_age  property_type_Bunglow  \
# price                     -0.005428               0.322641
# property_tax               0.012119               0.449372
# insurance                  0.075054               0.410135
# beds                      -0.015989               0.658729
# baths                     -0.213489               0.339109
# sqft                      -0.284702               0.525699
# lot_size                  -0.042227               0.250534
# basement                  -0.018488               0.253299
# popular                   -0.083813              -0.303769
# recession                  0.097146              -0.053224
# property_age               1.000000               0.224685
# property_type_Bunglow      0.224685               1.000000
# property_type_Condo       -0.224685              -1.000000
#
#                        property_type_Condo
# price                            -0.322641
# property_tax                     -0.449372
# insurance                        -0.410135
# beds                             -0.658729
# baths                            -0.339109
# sqft                             -0.525699
# lot_size                         -0.250534
# basement                         -0.253299
# popular                           0.303769
# recession                         0.053224
# property_age                     -0.224685
# property_type_Bunglow            -1.000000
# property_type_Condo               1.000000

# %% [markdown]
# #### From the observations above, answers the following questions:

# %% [markdown]
# Q1. Which model gave the lowest error? - 1 point

# %% [markdown]
# Ans:Random Forest Mode

# %% [markdown]
# Q2. Why was linear regression not a suitable choice for this data? - 1 point

# %% [markdown]
# Ans:Because the data is not linear.

# %% [markdown]
# Q3. Which are the top 5 important features in this dataset? - 1 point

# %% [markdown]
# Ans:lot_size, basement, popular, recession, property_age

# %% [markdown]
# ## Saving the Model

# %% [markdown]
# ## Pickle:
#
# * The pickle module implements a fundamental, but powerful algorithm for serializing and de-serializing a Python object structure.
#
# * The saving of data is called Serialization, while restoring the data is called Deserialization.
#
# **Pickle** model provides the following functions:
# * **`pickle.dump`** to serialize an object hierarchy, you simply use `dump()`.
# * **`pickle.load`** to deserialize a data stream, you call the `loads()` function.

# %%
# import pickle to save model
import pickle
 
# Save the trained model on the drive 
pickle.dump(lrmodel, open('RE_Model','wb'))

# %%
# Load the pickled model
RE_Model = pickle.load(open('RE_Model','rb'))

# %%
np.array(xtrain.loc[22])
# Out:
# array([139,  42,   1,   1, 703,   0,   1,   0,   0,  13,   0,   1],
#       dtype=int64)

# %%
ytrain[22]
# Out:
# 240000

# %%
df
# Out:
#        price  property_tax  insurance  beds  baths  sqft  lot_size  basement  \
# 0     295850           234         81     1      1   584         0         0
# 1     216500           169         51     1      1   612         0         1
# 2     279900           216         74     1      1   615         0         0
# 3     379900           265         92     1      1   618     33541         0
# 4     340000            88         30     1      1   634         0         0
# ...      ...           ...        ...   ...    ...   ...       ...       ...
# 1858  760000           881        249     5      5  7842    436035         1
# 1859  690000          1553        473     5      6  6501     23086         1
# 1860  600000           942        287     5      6  7064    217800         1
# 1861  759900           803        245     5      6  7500      8886         1
# 1862  735000          1459        444     5      6  7515     10497         1
#
#       popular  recession  property_age  property_type_Bunglow  \
# 0           0          1             0                      0
# 1           0          0            41                      0
# 2           0          1            49                      0
# 3           0          0             5                      0
# 4           0          0            10                      0
# ...       ...        ...           ...                    ...
# 1858        0          0             5                      1
# 1859        0          0            59                      1
# 1860        0          0             4                      1
# 1861        0          0             3                      1
# 1862        0          0            57                      1
#
#       property_type_Condo
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 1858                    0
# 1859                    0
# 1860                    0
# 1861                    0
# 1862                    0
#
# [1863 rows x 13 columns]

# %%
# Use the loaded pickled model to make predictions
RE_Model.predict([[139,  42,   1,   1, 703,   0,   1,  0,   0,   6,   1,  0]])
# Out:
# C:\Users\Samuel\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([277715.70738287])
